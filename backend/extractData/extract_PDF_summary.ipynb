# %%
import numpy as np
import pandas as pd
import re
from google.colab import drive
drive.mount("/drive")
# Out:
# Drive already mounted at /drive; to attempt to forcibly remount, call drive.mount("/drive", force_remount=True).

# %%
df = pd.read_excel('/drive/My Drive/6SP/logs.xlsx')
df_desc = df[df['Description'].notnull()] # remove rows with empty description field

# %%
def userId(desc):
    return desc.split()[4][1:-1]

# %%
df_desc['User_id'] = df_desc['Description'].apply(userId)
#df_desc.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_new = df_desc[df_desc['Event context'].notnull()] # remove rows with empty event context field
df_new.head()
# Out:
#               Time                   Event context Component  \
# 0  28/02/22, 10:56  Course: GP106-2021 : Computing      Logs
# 1  28/02/22, 10:56  Course: GP106-2021 : Computing    System
# 2  28/02/22, 10:04  Course: GP106-2021 : Computing    System
# 3  28/02/22, 09:23  Course: GP106-2021 : Computing    System
# 4  28/02/22, 09:23  Course: GP106-2021 : Computing    System
#
#           Event name                                        Description  \
# 0  Log report viewed  The user with id '2614' viewed the log report ...
# 1      Course viewed  The user with id '2614' viewed the course with...
# 2      Course viewed  The user with id '3740' viewed the course with...
# 3      Course viewed  The user with id '30' viewed the course with i...
# 4      Role assigned  The user with id '30' assigned the role with i...
#
#   Origin User_id
# 0    web    2614
# 1    web    2614
# 2    web    3740
# 3    web      30
# 4    web      30

# %%
# function to extract different event context types  
def extractEvent(eventContext):
  return eventContext.split(":")[0]

# %%
df_new['Event'] = df_new['Event context'].apply(extractEvent)
#df_new.head()

# %%
# extract only log records with event context type of "Label" and "File"
df_new = df_new[df_new.Event.isin(["Label","File"])]
#df_new.head()

# %%
# function to extract different event context types  2nd value given
def extractEventName(eventContext):
  return eventContext.split(":")[1]

# %%
df_new['EventName'] = df_new['Event context'].apply(extractEventName)
#df_new.head()

# %%
# function to extract status from event name field
def extractStatus(eventName):
  return eventName.split()[2]

# %%
# function to extract date
def extractDate(date_time):
  return date_time.split(",")[0]

# %%
df_new['Status'] = df_new['Event name'].apply(extractStatus)
df_new['Date'] = df_new['Time'].apply(extractDate)
#df_new.head()

# %%
# function to give type from Event context field
def extractType(eventContext):
  if (eventContext.split(":")[1][1:8] == 'Lecture') & (len(eventContext.split(":")[1]) < 15) :
    return "Video"
  elif (eventContext.split()[1][0:7] == 'Handout') :
    return "PDF"
  else:
    return "Other"

# %%
df_new['Type'] = df_new['Event context'].apply(extractType)
df_new.head()
# Out:
#                Time                                      Event context  \
# 14  28/02/22, 06:59                  File: GP106 Project Specification
# 15  28/02/22, 06:59  Label: GP106 Project\n\nInformation about the ...
# 16  28/02/22, 06:59                          Label: GP106 Labs: (copy)
# 21  28/02/22, 05:51                          File: Group List for Labs
# 24  28/02/22, 05:40                          File: Group List for Labs
#
#    Component                          Event name  \
# 14    System  Course activity completion updated
# 15    System  Course activity completion updated
# 16    System  Course activity completion updated
# 21      File                Course module viewed
# 24      File                Course module viewed
#
#                                           Description Origin User_id  Event  \
# 14  The user with id '3489' updated the completion...    web    3489   File
# 15  The user with id '3489' updated the completion...    web    3489  Label
# 16  The user with id '3489' updated the completion...    web    3489  Label
# 21  The user with id '3638' viewed the 'resource' ...    web    3638   File
# 24  The user with id '3638' viewed the 'resource' ...    web    3638   File
#
#                                             EventName      Status      Date  \
# 14                        GP106 Project Specification  completion  28/02/22
# 15   GP106 Project\n\nInformation about the projec...  completion  28/02/22
# 16                                         GP106 Labs  completion  28/02/22
# 21                                Group List for Labs      viewed  28/02/22
# 24                                Group List for Labs      viewed  28/02/22
#
#      Type
# 14  Other
# 15  Other
# 16  Other
# 21  Other
# 24  Other

# %%
# function to extract module Id from description field
def extractModuleID(desc):
  if (desc.split()[5] == 'updated'):
    return desc.split()[-7]
  else:
    return desc.split()[-1]

# %%
df_new['Module_id'] = df_new['Description'].apply(extractModuleID)
#df_new.head()

# %%
df_new = df_new.set_index('Status')
df_new = df_new.rename(index={'completion':'completed'})
#df_new.head()

# %%
df_new=df_new.reset_index()
#df_new.head()

# %%
df_new.rename(columns={'EventName': 'Material_name'}, inplace=True)
df_new.head()
# Out:
#       Status             Time  \
# 0  completed  28/02/22, 06:59
# 1  completed  28/02/22, 06:59
# 2  completed  28/02/22, 06:59
# 3     viewed  28/02/22, 05:51
# 4     viewed  28/02/22, 05:40
#
#                                        Event context Component  \
# 0                  File: GP106 Project Specification    System
# 1  Label: GP106 Project\n\nInformation about the ...    System
# 2                          Label: GP106 Labs: (copy)    System
# 3                          File: Group List for Labs      File
# 4                          File: Group List for Labs      File
#
#                            Event name  \
# 0  Course activity completion updated
# 1  Course activity completion updated
# 2  Course activity completion updated
# 3                Course module viewed
# 4                Course module viewed
#
#                                          Description Origin User_id  Event  \
# 0  The user with id '3489' updated the completion...    web    3489   File
# 1  The user with id '3489' updated the completion...    web    3489  Label
# 2  The user with id '3489' updated the completion...    web    3489  Label
# 3  The user with id '3638' viewed the 'resource' ...    web    3638   File
# 4  The user with id '3638' viewed the 'resource' ...    web    3638   File
#
#                                        Material_name      Date   Type  \
# 0                        GP106 Project Specification  28/02/22  Other
# 1   GP106 Project\n\nInformation about the projec...  28/02/22  Other
# 2                                         GP106 Labs  28/02/22  Other
# 3                                Group List for Labs  28/02/22  Other
# 4                                Group List for Labs  28/02/22  Other
#
#   Module_id
# 0   '49119'
# 1   '48654'
# 2   '48652'
# 3  '34437'.
# 4  '34437'.

# %%
#df_learningMaterials.to_csv("Learning_Materials_1.csv")

# %%
# function to remove other files which are not learning materials
def extractOther(eventContext):
  type = eventContext.split()[1][0:7]
  if(eventContext.split(":")[0] == 'Label'):
    if (type == 'Lecture') | (type == 'Lab') | (type == 'Old'):
      return 'True'
    else:
      return 'False'
  else:
    if (type == 'Dataset') | (type == 'Handout'):
      return "True"
    else:
      return "False"

# %%
df_new['Remove'] = df_new['Event context'].apply(extractOther)
#df_new.head()

# %%
df_new = df_new[df_new.Remove != 'False']
#df_new.head()

# %%
df_learningMaterials = df_new[['User_id','Material_name','Module_id','Type','Status','Date']]
df_learningMaterials.head()
# Out:
#    User_id Material_name Module_id Type  Status      Date
# 44    3391    Handout13   '42299'.  PDF  viewed  24/02/22
# 45    3391    Handout 14  '43550'.  PDF  viewed  24/02/22
# 62    3466    Handout 14  '43550'.  PDF  viewed  20/02/22
# 87    3648     Handout 7  '38179'.  PDF  viewed  19/02/22
# 94    3754     Handout 1  '33243'.  PDF  viewed  19/02/22

# %%
# df_learningMaterials.to_csv("Learning_Materials.csv")

# %%
df_pdf = df_learningMaterials[df_learningMaterials.Type != 'Video']
df_pdf = df_learningMaterials[df_learningMaterials.Type != 'Other']
df_pdf.head()
# Out:
#    User_id Material_name Module_id Type  Status      Date
# 44    3391    Handout13   '42299'.  PDF  viewed  24/02/22
# 45    3391    Handout 14  '43550'.  PDF  viewed  24/02/22
# 62    3466    Handout 14  '43550'.  PDF  viewed  20/02/22
# 87    3648     Handout 7  '38179'.  PDF  viewed  19/02/22
# 94    3754     Handout 1  '33243'.  PDF  viewed  19/02/22

# %%
ar=df_pdf.Material_name.unique() #35
len(ar)
# Out:
# 35

# %%
df_pdf.to_csv("PDFNames.csv")

# %%
df_pdf = df_pdf[df_pdf.Status != 'updated']
df_pdf = df_pdf[df_pdf.Status != 'created']
#df_pdf = df_pdf[df_pdf.Status != 'completed']
df_pdf.head()
# Out:
#    User_id Material_name Module_id Type  Status      Date
# 44    3391    Handout13   '42299'.  PDF  viewed  24/02/22
# 45    3391    Handout 14  '43550'.  PDF  viewed  24/02/22
# 62    3466    Handout 14  '43550'.  PDF  viewed  20/02/22
# 87    3648     Handout 7  '38179'.  PDF  viewed  19/02/22
# 94    3754     Handout 1  '33243'.  PDF  viewed  19/02/22

# %%
ar=df_pdf.Material_name.unique() #26
len(ar)
# Out:
# 26

# %%
df_pdfViews=df_pdf.groupby(["Material_name"])["User_id"].count().reset_index(name="Count")
df_pdfViews
# Out:
#                    Material_name  Count
# 0                      Handout 1   1418
# 1             Handout 10 Modules    849
# 2                    Handout 11     901
# 3                     Handout 12    814
# 4                     Handout 14    722
# 5                      Handout 2   1447
# 6                      Handout 3   1910
# 7         Handout 5 - Flowcharts   1035
# 8                      Handout 6    887
# 9                      Handout 7   1209
# 10         Handout 8 - Functions    681
# 11                     Handout 9    803
# 12                    Handout13    1566
# 13   Handout4 PythonProgramming2   2098
# 14                     Lecture 1    289
# 15                    Lecture 14    130
# 16                    Lecture 15    129
# 17                    Lecture 16     93
# 18                    Lecture 17     80
# 19                     Lecture 2    269
# 20                     Lecture 3    221
# 21                     Lecture 4    228
# 22                     Lecture 5    176
# 23                    Lecture 6     152
# 24                     Lecture 7    155
# 25                     Lecture 8    152

# %%
df_pdfViews.to_csv("PDF_Views_Completed.csv")
