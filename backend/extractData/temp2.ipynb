# %%
import pandas as pd

# %%
pd.options.mode.chained_assignment = None

# %%
import numpy as np

# %%
from google.colab import drive
drive.mount("/drive")
# Out:
# Mounted at /drive

# %%
df = pd.read_excel('/drive/My Drive/logs.xlsx')

# %%
def getNoOfLogRecords():

  # get number of log records 
  noOfLogRecords = df.shape[0]

  return noOfLogRecords
getNoOfLogRecords()
# Out:
# 455237

# %%
des = df[df['Description'].notnull()]

# %%
def userId(desc):
    return desc.split()[4][1:-1]

# %%
des['user'] = des['Description'].apply(userId)
des.head()
# Out:
#               Time                   Event context Component  \
# 0  28/02/22, 10:56  Course: GP106-2021 : Computing      Logs
# 1  28/02/22, 10:56  Course: GP106-2021 : Computing    System
# 2  28/02/22, 10:04  Course: GP106-2021 : Computing    System
# 3  28/02/22, 09:23  Course: GP106-2021 : Computing    System
# 4  28/02/22, 09:23  Course: GP106-2021 : Computing    System
#
#           Event name                                        Description  \
# 0  Log report viewed  The user with id '2614' viewed the log report ...
# 1      Course viewed  The user with id '2614' viewed the course with...
# 2      Course viewed  The user with id '3740' viewed the course with...
# 3      Course viewed  The user with id '30' viewed the course with i...
# 4      Role assigned  The user with id '30' assigned the role with i...
#
#   Origin  user
# 0    web  2614
# 1    web  2614
# 2    web  3740
# 3    web    30
# 4    web    30

# %%
file = df[df['Event context'].notnull()]

def materials(file):
  if file[0:4] == 'File':
    return file

#newfile = file['Event context'].apply(materials)
i =0
arr1 = set()
while i<len(file):
  newfile = materials(file['Event context'][i])
  if newfile != None:
    arr1.add(file['Event context'][i])
  i = i+1
#arr1
#file.iloc[0]

# %%
# Event context--> 'Course: (different types)'
course = df[df['Event context'].notnull()]

def materials1(course):
  if course[0:6] == 'Course':
    return course

#newfile = file['Event context'].apply(materials)
i =0
arr2 = set()
while i<len(course):
  newcourse = materials1(course['Event context'][i])
  if newcourse != None:
    arr2.add(course['Event context'][i])
  i = i+1
arr2
# Out:
# {'Course: GP106-2021 : Computing'}

# %%
#different Event context types
lm = df[df['Event context'].notnull()]

arrnew = set()
i=0
while i<len(lm):
  category = lm['Event context'][i].split(":")[0]
  arrnew.add(category)
  i = i+1
arrnew
# Out:
# {'Assignment',
#  'Course',
#  'Feedback',
#  'File',
#  'Forum',
#  'Interactive Content',
#  'Label',
#  'Other',
#  'Page',
#  'Quiz',
#  'URL'}

# %%
# Event context--> 'URL: (different types)'
url = df[df['Event context'].notnull()]

def materials2(url):
  if url[0:3] == 'URL':
    return url

#newfile = file['Event context'].apply(materials)
i =0
arr3 = set()
while i<len(url):
  newurl = materials2(url['Event context'][i])
  if newurl != None:
    arr3.add(url['Event context'][i])
  i = i+1
arr3
# Out:
# {'URL: GP106 Group Project Discussion Slack Channel',
#  'URL: GP106 Project Groups',
#  'URL: GP106 Project Kits Collection Form',
#  'URL: Signal Group Link for "GP106 - 2021 Official"'}

# %%
# Event context--> 'Interactive: (different types)'
interactive = df[df['Event context'].notnull()]

def materials3(interactive):
  if interactive[0:19] == 'Interactive Content':
    return interactive

#newfile = file['Event context'].apply(materials)
i =0
arr4 = set()
while i<len(interactive):
  newinter = materials3(interactive['Event context'][i])
  if newinter != None:
    arr4.add(interactive['Event context'][i])
  i = i+1
arr4
# Out:
# {'Interactive Content: Interactive Activity - Computing Basics'}

# %%
# Event context--> 'Label: (different types)'
label = df[df['Event context'].notnull()]

def materials4(label):
  if label[0:5] == 'Label':
    return label

#newfile = file['Event context'].apply(materials)
i =0
arr5 = set()
while i<len(label):
  newlabel = materials4(label['Event context'][i])
  if newlabel != None:
    arr5.add(label['Event context'][i])
  i = i+1
arr5
# Out:
# {'Label: Exam Instructions (08/09/2021):\nMid-semester exam...',
#  'Label: Feedback:',
#  'Label: GP106 Labs: (copy)',
#  'Label: GP106 Project\n\nInformation about the project wil...',
#  'Label: Lab Materials :',
#  'Label: Lecture 10: Modules, Documentation and Testing\n\n...',
#  'Label: Lecture 13: Data Structures and Object-Oriented Pr...',
#  'Label: Lecture 14: OOP and Vectors and Matrices\nzoom_0.m...',
#  'Label: Lecture 15: Vectors and Matrices (Part II) and Plo...',
#  'Label: Lecture 16: Plotting (Part II)\nzoom_0.mp4',
#  'Label: Lecture 17: Data Structures and OOP\n\n\nzoom_0.mp...',
#  'Label: Lecture 17: GUI in Python\nzoom_1.mp4',
#  'Label: Lecture 18: Vectors and Matrices - part I\nzoom_0....',
#  'Label: Lecture 19: Vectors and Matrices part II\nzoom_0.m...',
#  'Label: Lecture 1: Introduction and Data representation (p...',
#  'Label: Lecture 20: Vectors and Matrices part III\nzoom_0....',
#  'Label: Lecture 21: Vectors and Matrices part IV\n\nout.mp...',
#  'Label: Lecture 22: Plotting 2D and 3D Graphs part I\n\nzo...',
#  'Label: Lecture 23: Plotting 2D and 3D Graphs part II\n\nz...',
#  'Label: Lecture 2: Data Representation (part II)\nzoom_0.m...',
#  'Label: Lecture 3: Python Programming\nzoom_0.mp4',
#  'Label: Lecture 4: Python Programming - Input/Output\nzoom...',
#  'Label: Lecture 5: Operators and Flowcharts\nzoom_0.mp4',
#  'Label: Lecture 6 : Flowcharts II\nzoom_0.mp4',
#  'Label: Lecture 7: Control Structures in Python I\nzoom_0....',
#  'Label: Lecture 8: Control Structures II, Jump Statements,...',
#  'Label: Lecture 9: Functions II, File Handling, Modules (i...',
#  'Label: Lecture Materials :',
#  'Label: Lecture Materials : (copy)',
#  'Label: Lecture Materials : (copy) (copy)',
#  'Label: Old Lectures',
#  'Label: Update (07/09/2021): The mock examination will be ...'}

# %%
# Event context--> 'Page: (different types)'
page = df[df['Event context'].notnull()]

def materials5(page):
  if page[0:4] == 'Page':
    return page

#newfile = file['Event context'].apply(materials)
i =0
arr6 = set()
while i<len(page):
  newpage = materials5(page['Event context'][i])
  if newpage != None:
    arr6.add(page['Event context'][i])
  i = i+1
arr6
# Out:
# {'Page: GP106 - Lab Guidelines'}

# %%
# Event context--> 'Other: (different types)'
other = df[df['Event context'].notnull()]

def materials6(other):
  if other[0:5] == 'Other':
    return other

#newfile = file['Event context'].apply(materials)
i =0
arr7 = set()
while i<len(other):
  newother = materials6(other['Event context'][i])
  if newother != None:
    arr7.add(other['Event context'][i])
  i = i+1
arr7
# Out:
# {'Other'}

# %%
# Event context--> 'Assignment: (different types)'
assignment = df[df['Event context'].notnull()]

def materials7(assignment):
  if assignment[0:10] == 'Assignment':
    return assignment

#newfile = file['Event context'].apply(materials)
i =0
arr8 = set()
while i<len(assignment):
  newassignment = materials7(assignment['Event context'][i])
  if newassignment != None:
    arr8.add(assignment['Event context'][i])
  i = i+1
arr8
# Out:
# {'Assignment: Answers and rough work of Mock Examination',
#  'Assignment: Lab 01 -Submission for Lab Exercise - Group AB',
#  'Assignment: Lab 01 -Submission for Lab Exercise - Group CD',
#  'Assignment: Lab 02 - Submission - Group AB',
#  'Assignment: Lab 02 - Submission - Group CD',
#  'Assignment: Lab 03 - Submission - Group AB',
#  'Assignment: Lab 03 - Submission - Group CD',
#  'Assignment: Lab 04 - Submission - Group AB',
#  'Assignment: Lab 04 - Submission - Group CD',
#  'Assignment: Lab 05 - Submission - Group AB',
#  'Assignment: Lab 05 - Submission - Group CD',
#  'Assignment: Lab 06 - Submission - Group AB',
#  'Assignment: Lab 06 - Submission - Group CD',
#  'Assignment: Lab 08 - Submission',
#  'Assignment: Revision Lab - AB - Submission',
#  'Assignment: Revision Lab - CD - Submission'}

# %%
# Event context--> 'Quiz: (type)' with user id
quiz = df[df['Event context'].notnull()]

def materials8(quiz):
  if quiz[0:4] == 'Quiz':
    return quiz

#newfile = file['Event context'].apply(materials)
i =0
arr9 = set()
Dict = {}
while i<len(quiz):
  newquiz = materials8(quiz['Event context'][i])
  if newquiz != None:
    arr9.add(quiz['Event context'][i])
    Dict[des['user'][i]] = quiz['Event context'][i]
  i = i+1
arr9
Dict
# Out:
# {'1661': 'Quiz: Quiz 01 - Group AB, CD',
#  '2155': 'Quiz: Quiz 01 - Group AB, CD',
#  '2613': 'Quiz: Quiz 01 - Group AB, CD',
#  '3385': 'Quiz: Quiz 01 - Group AB, CD',
#  '3386': 'Quiz: Quiz 01 - Group AB, CD',
#  '3387': 'Quiz: Quiz 01 - Group AB, CD',
#  '3388': 'Quiz: Quiz 01 - Group AB, CD',
#  '3389': 'Quiz: Quiz 01 - Group AB, CD',
#  '3390': 'Quiz: Quiz 01 - Group AB, CD',
#  '3391': 'Quiz: Quiz 01 - Group AB, CD',
#  '3392': 'Quiz: Quiz 01 - Group AB, CD',
#  '3393': 'Quiz: Quiz 01 - Group AB, CD',
#  '3394': 'Quiz: Quiz 01 - Group AB, CD',
#  '3395': 'Quiz: Quiz 01 - Group AB, CD',
#  '3396': 'Quiz: Quiz 01 - Group AB, CD',
#  '3397': 'Quiz: Quiz 01 - Group AB, CD',
#  '3398': 'Quiz: Quiz 01 - Group AB, CD',
#  '3399': 'Quiz: Quiz 01 - Group AB, CD',
#  '3400': 'Quiz: Quiz 01 - Group AB, CD',
#  '3401': 'Quiz: Quiz 01 - Group AB, CD',
#  '3402': 'Quiz: Quiz 01 - Group AB, CD',
#  '3403': 'Quiz: Quiz 01 - Group AB, CD',
#  '3404': 'Quiz: Quiz 01 - Group AB, CD',
#  '3405': 'Quiz: Quiz 01 - Group AB, CD',
#  '3406': 'Quiz: Quiz 01 - Group AB, CD',
#  '3407': 'Quiz: Quiz 01 - Group AB, CD',
#  '3409': 'Quiz: Quiz 01 - Group AB, CD',
#  '3410': 'Quiz: Quiz 01 - Group AB, CD',
#  '3411': 'Quiz: Quiz 01 - Group AB, CD',
#  '3412': 'Quiz: Quiz 01 - Group AB, CD',
#  '3413': 'Quiz: Quiz 01 - Group AB, CD',
#  '3414': 'Quiz: Quiz 01 - Group AB, CD',
#  '3415': 'Quiz: Quiz 01 - Group AB, CD',
#  '3416': 'Quiz: Quiz 01 - Group AB, CD',
#  '3417': 'Quiz: Quiz 01 - Group AB, CD',
#  '3418': 'Quiz: Quiz 01 - Group AB, CD',
#  '3419': 'Quiz: Quiz 01 - Group AB, CD',
#  '3420': 'Quiz: Quiz 01 - Group AB, CD',
#  '3421': 'Quiz: Quiz 01 - Group AB, CD',
#  '3422': 'Quiz: Quiz 01 - Group AB, CD',
#  '3423': 'Quiz: Quiz 01 - Group AB, CD',
#  '3424': 'Quiz: Quiz 01 - Group AB, CD',
#  '3425': 'Quiz: Quiz 01 - Group AB, CD',
#  '3426': 'Quiz: Quiz 01 - Group AB, CD',
#  '3427': 'Quiz: Quiz 01 - Group AB, CD',
#  '3428': 'Quiz: Quiz 01 - Group AB, CD',
#  '3429': 'Quiz: Quiz 01 - Group AB, CD',
#  '3431': 'Quiz: Quiz 01 - Group AB, CD',
#  '3433': 'Quiz: Quiz 01 - Group AB, CD',
#  '3434': 'Quiz: Quiz 01 - Group AB, CD',
#  '3435': 'Quiz: Quiz 01 - Group AB, CD',
#  '3436': 'Quiz: Quiz 01 - Group AB, CD',
#  '3437': 'Quiz: Quiz 01 - Group AB, CD',
#  '3438': 'Quiz: Quiz 01 - Group AB, CD',
#  '3439': 'Quiz: Quiz 01 - Group AB, CD',
#  '3440': 'Quiz: Quiz 01 - Group AB, CD',
#  '3441': 'Quiz: Quiz 01 - Group AB, CD',
#  '3442': 'Quiz: Quiz 01 - Group AB, CD',
#  '3443': 'Quiz: Quiz 01 - Group AB, CD',
#  '3444': 'Quiz: Quiz 01 - Group AB, CD',
#  '3446': 'Quiz: Quiz 01 - Group AB, CD',
#  '3447': 'Quiz: Quiz 01 - Group AB, CD',
#  '3448': 'Quiz: Quiz 01 - Group AB, CD',
#  '3449': 'Quiz: Quiz 01 - Group AB, CD',
#  '3450': 'Quiz: Quiz 01 - Group AB, CD',
#  '3451': 'Quiz: Quiz 01 - Group AB, CD',
#  '3453': 'Quiz: Quiz 01 - Group AB, CD',
#  '3454': 'Quiz: Quiz 01 - Group AB, CD',
#  '3455': 'Quiz: Quiz 01 - Group AB, CD',
#  '3456': 'Quiz: Quiz 01 - Group AB, CD',
#  '3457': 'Quiz: Quiz 01 - Group AB, CD',
#  '3458': 'Quiz: Quiz 01 - Group AB, CD',
#  '3459': 'Quiz: Quiz 01 - Group AB, CD',
#  '3460': 'Quiz: Quiz 01 - Group AB, CD',
#  '3461': 'Quiz: Quiz 01 - Group AB, CD',
#  '3462': 'Quiz: Quiz 01 - Group AB, CD',
#  '3463': 'Quiz: Quiz 01 - Group AB, CD',
#  '3464': 'Quiz: Quiz 01 - Group AB, CD',
#  '3465': 'Quiz: Quiz 01 - Group AB, CD',
#  '3466': 'Quiz: Quiz 01 - Group AB, CD',
#  '3467': 'Quiz: Quiz 01 - Group AB, CD',
#  '3468': 'Quiz: Quiz 01 - Group AB, CD',
#  '3469': 'Quiz: Quiz 01 - Group AB, CD',
#  '3470': 'Quiz: Quiz 01 - Group AB, CD',
#  '3471': 'Quiz: Quiz 01 - Group AB, CD',
#  '3472': 'Quiz: Quiz 01 - Group AB, CD',
#  '3473': 'Quiz: Quiz 01 - Group AB, CD',
#  '3474': 'Quiz: Quiz 01 - Group AB, CD',
#  '3475': 'Quiz: Quiz 01 - Group AB, CD',
#  '3476': 'Quiz: Quiz 01 - Group AB, CD',
#  '3477': 'Quiz: Quiz 01 - Group AB, CD',
#  '3478': 'Quiz: Quiz 01 - Group AB, CD',
#  '3479': 'Quiz: Quiz 01 - Group AB, CD',
#  '3480': 'Quiz: Quiz 01 - Group AB, CD',
#  '3481': 'Quiz: Quiz 01 - Group AB, CD',
#  '3482': 'Quiz: Quiz 01 - Group AB, CD',
#  '3483': 'Quiz: Quiz 01 - Group AB, CD',
#  '3484': 'Quiz: Quiz 01 - Group AB, CD',
#  '3485': 'Quiz: Quiz 01 - Group AB, CD',
#  '3486': 'Quiz: Quiz 01 - Group AB, CD',
#  '3487': 'Quiz: Quiz 01 - Group AB, CD',
#  '3488': 'Quiz: Quiz 01 - Group AB, CD',
#  '3489': 'Quiz: Quiz 01 - Group AB, CD',
#  '3490': 'Quiz: Quiz 01 - Group AB, CD',
#  '3491': 'Quiz: Quiz 01 - Group AB, CD',
#  '3492': 'Quiz: Quiz 01 - Group AB, CD',
#  '3493': 'Quiz: Quiz 01 - Group AB, CD',
#  '3494': 'Quiz: Quiz 01 - Group AB, CD',
#  '3495': 'Quiz: Quiz 01 - Group AB, CD',
#  '3496': 'Quiz: Quiz 01 - Group AB, CD',
#  '3497': 'Quiz: Quiz 01 - Group AB, CD',
#  '3498': 'Quiz: Quiz 01 - Group AB, CD',
#  '3499': 'Quiz: Quiz 01 - Group AB, CD',
#  '3500': 'Quiz: Quiz 01 - Group AB, CD',
#  '3501': 'Quiz: Quiz 01 - Group AB, CD',
#  '3502': 'Quiz: Quiz 01 - Group AB, CD',
#  '3503': 'Quiz: Quiz 01 - Group AB, CD',
#  '3504': 'Quiz: Quiz 01 - Group AB, CD',
#  '3506': 'Quiz: Quiz 01 - Group AB, CD',
#  '3507': 'Quiz: Quiz 01 - Group AB, CD',
#  '3508': 'Quiz: Quiz 01 - Group AB, CD',
#  '3509': 'Quiz: Quiz 01 - Group AB, CD',
#  '3510': 'Quiz: Quiz 01 - Group AB, CD',
#  '3511': 'Quiz: Quiz 01 - Group AB, CD',
#  '3512': 'Quiz: Quiz 01 - Group AB, CD',
#  '3513': 'Quiz: Quiz 01 - Group AB, CD',
#  '3514': 'Quiz: Quiz 01 - Group AB, CD',
#  '3515': 'Quiz: Quiz 01 - Group AB, CD',
#  '3516': 'Quiz: Quiz 01 - Group AB, CD',
#  '3517': 'Quiz: Quiz 01 - Group AB, CD',
#  '3518': 'Quiz: Quiz 01 - Group AB, CD',
#  '3519': 'Quiz: Quiz 01 - Group AB, CD',
#  '3520': 'Quiz: Quiz 01 - Group AB, CD',
#  '3521': 'Quiz: Quiz 01 - Group AB, CD',
#  '3522': 'Quiz: Quiz 01 - Group AB, CD',
#  '3523': 'Quiz: Quiz 01 - Group AB, CD',
#  '3525': 'Quiz: Quiz 01 - Group AB, CD',
#  '3526': 'Quiz: Quiz 01 - Group AB, CD',
#  '3527': 'Quiz: Quiz 01 - Group AB, CD',
#  '3528': 'Quiz: Quiz 01 - Group AB, CD',
#  '3529': 'Quiz: Quiz 01 - Group AB, CD',
#  '3530': 'Quiz: Quiz 01 - Group AB, CD',
#  '3531': 'Quiz: Quiz 01 - Group AB, CD',
#  '3532': 'Quiz: Quiz 01 - Group AB, CD',
#  '3533': 'Quiz: Quiz 01 - Group AB, CD',
#  '3534': 'Quiz: Quiz 01 - Group AB, CD',
#  '3535': 'Quiz: Quiz 01 - Group AB, CD',
#  '3536': 'Quiz: Quiz 01 - Group AB, CD',
#  '3537': 'Quiz: Quiz 01 - Group AB, CD',
#  '3538': 'Quiz: Quiz 01 - Group AB, CD',
#  '3539': 'Quiz: Quiz 01 - Group AB, CD',
#  '3540': 'Quiz: Quiz 01 - Group AB, CD',
#  '3541': 'Quiz: Quiz 01 - Group AB, CD',
#  '3542': 'Quiz: Quiz 01 - Group AB, CD',
#  '3543': 'Quiz: Quiz 01 - Group AB, CD',
#  '3544': 'Quiz: Quiz 01 - Group AB, CD',
#  '3545': 'Quiz: Quiz 01 - Group AB, CD',
#  '3546': 'Quiz: Quiz 01 - Group AB, CD',
#  '3547': 'Quiz: Quiz 01 - Group AB, CD',
#  '3548': 'Quiz: Quiz 01 - Group AB, CD',
#  '3549': 'Quiz: Quiz 01 - Group AB, CD',
#  '3550': 'Quiz: Quiz 01 - Group AB, CD',
#  '3551': 'Quiz: Quiz 01 - Group AB, CD',
#  '3552': 'Quiz: Quiz 01 - Group AB, CD',
#  '3553': 'Quiz: Quiz 01 - Group AB, CD',
#  '3554': 'Quiz: Quiz 01 - Group AB, CD',
#  '3555': 'Quiz: Quiz 01 - Group AB, CD',
#  '3556': 'Quiz: Quiz 01 - Group AB, CD',
#  '3557': 'Quiz: Quiz 01 - Group AB, CD',
#  '3558': 'Quiz: Quiz 01 - Group AB, CD',
#  '3559': 'Quiz: Quiz 01 - Group AB, CD',
#  '3560': 'Quiz: Quiz 01 - Group AB, CD',
#  '3561': 'Quiz: Quiz 01 - Group AB, CD',
#  '3562': 'Quiz: Quiz 01 - Group AB, CD',
#  '3563': 'Quiz: Quiz 01 - Group AB, CD',
#  '3564': 'Quiz: Quiz 01 - Group AB, CD',
#  '3565': 'Quiz: Quiz 01 - Group AB, CD',
#  '3566': 'Quiz: Quiz 01 - Group AB, CD',
#  '3567': 'Quiz: Quiz 01 - Group AB, CD',
#  '3568': 'Quiz: Quiz 01 - Group AB, CD',
#  '3569': 'Quiz: Quiz 01 - Group AB, CD',
#  '3570': 'Quiz: Quiz 01 - Group AB, CD',
#  '3572': 'Quiz: Quiz 01 - Group AB, CD',
#  '3573': 'Quiz: Quiz 01 - Group AB, CD',
#  '3574': 'Quiz: Quiz 01 - Group AB, CD',
#  '3575': 'Quiz: Quiz 01 - Group AB, CD',
#  '3576': 'Quiz: Quiz 01 - Group AB, CD',
#  '3577': 'Quiz: Quiz 01 - Group AB, CD',
#  '3578': 'Quiz: Quiz 01 - Group AB, CD',
#  '3579': 'Quiz: Quiz 01 - Group AB, CD',
#  '3580': 'Quiz: Quiz 01 - Group AB, CD',
#  '3581': 'Quiz: Quiz 01 - Group AB, CD',
#  '3582': 'Quiz: Quiz 01 - Group AB, CD',
#  '3584': 'Quiz: Quiz 01 - Group AB, CD',
#  '3585': 'Quiz: Quiz 01 - Group AB, CD',
#  '3586': 'Quiz: Quiz 01 - Group AB, CD',
#  '3587': 'Quiz: Quiz 01 - Group AB, CD',
#  '3588': 'Quiz: Quiz 01 - Group AB, CD',
#  '3589': 'Quiz: Quiz 01 - Group AB, CD',
#  '3590': 'Quiz: Quiz 01 - Group AB, CD',
#  '3591': 'Quiz: Quiz 01 - Group AB, CD',
#  '3592': 'Quiz: Quiz 01 - Group AB, CD',
#  '3593': 'Quiz: Quiz 01 - Group AB, CD',
#  '3594': 'Quiz: Quiz 01 - Group AB, CD',
#  '3595': 'Quiz: Quiz 01 - Group AB, CD',
#  '3596': 'Quiz: Quiz 01 - Group AB, CD',
#  '3597': 'Quiz: Quiz 01 - Group AB, CD',
#  '3598': 'Quiz: Quiz 01 - Group AB, CD',
#  '3599': 'Quiz: Quiz 01 - Group AB, CD',
#  '3600': 'Quiz: Quiz 01 - Group AB, CD',
#  '3601': 'Quiz: Quiz 01 - Group AB, CD',
#  '3602': 'Quiz: Quiz 01 - Group AB, CD',
#  '3603': 'Quiz: Quiz 01 - Group AB, CD',
#  '3604': 'Quiz: Quiz 01 - Group AB, CD',
#  '3605': 'Quiz: Quiz 01 - Group AB, CD',
#  '3606': 'Quiz: Quiz 01 - Group AB, CD',
#  '3607': 'Quiz: Quiz 01 - Group AB, CD',
#  '3608': 'Quiz: Quiz 01 - Group AB, CD',
#  '3610': 'Quiz: Quiz 01 - Group AB, CD',
#  '3611': 'Quiz: Quiz 01 - Group AB, CD',
#  '3612': 'Quiz: Quiz 01 - Group AB, CD',
#  '3614': 'Quiz: Quiz 01 - Group AB, CD',
#  '3615': 'Quiz: Quiz 01 - Group AB, CD',
#  '3617': 'Quiz: Quiz 01 - Group AB, CD',
#  '3618': 'Quiz: Quiz 01 - Group AB, CD',
#  '3619': 'Quiz: Quiz 01 - Group AB, CD',
#  '3620': 'Quiz: Quiz 01 - Group AB, CD',
#  '3621': 'Quiz: Quiz 01 - Group AB, CD',
#  '3622': 'Quiz: Quiz 01 - Group AB, CD',
#  '3623': 'Quiz: Quiz 01 - Group AB, CD',
#  '3624': 'Quiz: Quiz 01 - Group AB, CD',
#  '3625': 'Quiz: Quiz 01 - Group AB, CD',
#  '3626': 'Quiz: Quiz 01 - Group AB, CD',
#  '3627': 'Quiz: Quiz 01 - Group AB, CD',
#  '3628': 'Quiz: Quiz 01 - Group AB, CD',
#  '3629': 'Quiz: Quiz 01 - Group AB, CD',
#  '3630': 'Quiz: Quiz 01 - Group AB, CD',
#  '3631': 'Quiz: Quiz 01 - Group AB, CD',
#  '3632': 'Quiz: Quiz 01 - Group AB, CD',
#  '3633': 'Quiz: Quiz 01 - Group AB, CD',
#  '3635': 'Quiz: Quiz 01 - Group AB, CD',
#  '3636': 'Quiz: Quiz 01 - Group AB, CD',
#  '3637': 'Quiz: Quiz 01 - Group AB, CD',
#  '3638': 'Quiz: Quiz 01 - Group AB, CD',
#  '3639': 'Quiz: Quiz 01 - Group AB, CD',
#  '3640': 'Quiz: Quiz 01 - Group AB, CD',
#  '3641': 'Quiz: Quiz 01 - Group AB, CD',
#  '3642': 'Quiz: Quiz 01 - Group AB, CD',
#  '3643': 'Quiz: Quiz 01 - Group AB, CD',
#  '3644': 'Quiz: Quiz 01 - Group AB, CD',
#  '3645': 'Quiz: Quiz 01 - Group AB, CD',
#  '3646': 'Quiz: Quiz 01 - Group AB, CD',
#  '3647': 'Quiz: Quiz 01 - Group AB, CD',
#  '3648': 'Quiz: Quiz 01 - Group AB, CD',
#  '3649': 'Quiz: Quiz 01 - Group AB, CD',
#  '3650': 'Quiz: Quiz 01 - Group AB, CD',
#  '3651': 'Quiz: Quiz 01 - Group AB, CD',
#  '3652': 'Quiz: Quiz 01 - Group AB, CD',
#  '3653': 'Quiz: Quiz 01 - Group AB, CD',
#  '3654': 'Quiz: Quiz 01 - Group AB, CD',
#  '3655': 'Quiz: Quiz 01 - Group AB, CD',
#  '3656': 'Quiz: Quiz 01 - Group AB, CD',
#  '3657': 'Quiz: Quiz 01 - Group AB, CD',
#  '3658': 'Quiz: Quiz 01 - Group AB, CD',
#  '3659': 'Quiz: Quiz 01 - Group AB, CD',
#  '3660': 'Quiz: Quiz 01 - Group AB, CD',
#  '3661': 'Quiz: Quiz 01 - Group AB, CD',
#  '3662': 'Quiz: Quiz 01 - Group AB, CD',
#  '3663': 'Quiz: Quiz 01 - Group AB, CD',
#  '3664': 'Quiz: Quiz 01 - Group AB, CD',
#  '3665': 'Quiz: Quiz 01 - Group AB, CD',
#  '3667': 'Quiz: Quiz 01 - Group AB, CD',
#  '3669': 'Quiz: Quiz 01 - Group AB, CD',
#  '3670': 'Quiz: Quiz 01 - Group AB, CD',
#  '3671': 'Quiz: Quiz 01 - Group AB, CD',
#  '3672': 'Quiz: Quiz 01 - Group AB, CD',
#  '3673': 'Quiz: Quiz 01 - Group AB, CD',
#  '3674': 'Quiz: Quiz 01 - Group AB, CD',
#  '3675': 'Quiz: Quiz 01 - Group AB, CD',
#  '3676': 'Quiz: Quiz 01 - Group AB, CD',
#  '3678': 'Quiz: Quiz 01 - Group AB, CD',
#  '3679': 'Quiz: Quiz 01 - Group AB, CD',
#  '3680': 'Quiz: Quiz 01 - Group AB, CD',
#  '3681': 'Quiz: Quiz 01 - Group AB, CD',
#  '3682': 'Quiz: Quiz 01 - Group AB, CD',
#  '3683': 'Quiz: Quiz 01 - Group AB, CD',
#  '3684': 'Quiz: Quiz 01 - Group AB, CD',
#  '3685': 'Quiz: Quiz 01 - Group AB, CD',
#  '3687': 'Quiz: Quiz 01 - Group AB, CD',
#  '3688': 'Quiz: Quiz 01 - Group AB, CD',
#  '3689': 'Quiz: Quiz 01 - Group AB, CD',
#  '3690': 'Quiz: Quiz 01 - Group AB, CD',
#  '3692': 'Quiz: Quiz 01 - Group AB, CD',
#  '3693': 'Quiz: Quiz 01 - Group AB, CD',
#  '3694': 'Quiz: Quiz 01 - Group AB, CD',
#  '3695': 'Quiz: Quiz 01 - Group AB, CD',
#  '3696': 'Quiz: Quiz 01 - Group AB, CD',
#  '3697': 'Quiz: Quiz 01 - Group AB, CD',
#  '3698': 'Quiz: Quiz 01 - Group AB, CD',
#  '3699': 'Quiz: Quiz 01 - Group AB, CD',
#  '3700': 'Quiz: Quiz 01 - Group AB, CD',
#  '3702': 'Quiz: Quiz 01 - Group AB, CD',
#  '3703': 'Quiz: Quiz 01 - Group AB, CD',
#  '3704': 'Quiz: Quiz 01 - Group AB, CD',
#  '3705': 'Quiz: Quiz 01 - Group AB, CD',
#  '3706': 'Quiz: Quiz 01 - Group AB, CD',
#  '3707': 'Quiz: Quiz 01 - Group AB, CD',
#  '3708': 'Quiz: Quiz 01 - Group AB, CD',
#  '3709': 'Quiz: Quiz 01 - Group AB, CD',
#  '3710': 'Quiz: Quiz 01 - Group AB, CD',
#  '3711': 'Quiz: Quiz 01 - Group AB, CD',
#  '3712': 'Quiz: Quiz 01 - Group AB, CD',
#  '3713': 'Quiz: Quiz 01 - Group AB, CD',
#  '3714': 'Quiz: Quiz 01 - Group AB, CD',
#  '3715': 'Quiz: Quiz 01 - Group AB, CD',
#  '3716': 'Quiz: Quiz 01 - Group AB, CD',
#  '3717': 'Quiz: Quiz 01 - Group AB, CD',
#  '3718': 'Quiz: Quiz 01 - Group AB, CD',
#  '3719': 'Quiz: Quiz 01 - Group AB, CD',
#  '3720': 'Quiz: Quiz 01 - Group AB, CD',
#  '3721': 'Quiz: Quiz 01 - Group AB, CD',
#  '3722': 'Quiz: Quiz 01 - Group AB, CD',
#  '3724': 'Quiz: Quiz 01 - Group AB, CD',
#  '3725': 'Quiz: Quiz 01 - Group AB, CD',
#  '3726': 'Quiz: Quiz 01 - Group AB, CD',
#  '3727': 'Quiz: Quiz 01 - Group AB, CD',
#  '3728': 'Quiz: Quiz 01 - Group AB, CD',
#  '3729': 'Quiz: Quiz 01 - Group AB, CD',
#  '3730': 'Quiz: Quiz 01 - Group AB, CD',
#  '3732': 'Quiz: Quiz 01 - Group AB, CD',
#  '3733': 'Quiz: Quiz 01 - Group AB, CD',
#  '3734': 'Quiz: Quiz 01 - Group AB, CD',
#  '3735': 'Quiz: Quiz 01 - Group AB, CD',
#  '3736': 'Quiz: Quiz 01 - Group AB, CD',
#  '3737': 'Quiz: Quiz 01 - Group AB, CD',
#  '3738': 'Quiz: Quiz 01 - Group AB, CD',
#  '3739': 'Quiz: Quiz 01 - Group AB, CD',
#  '3740': 'Quiz: Quiz 01 - Group AB, CD',
#  '3741': 'Quiz: Quiz 01 - Group AB, CD',
#  '3743': 'Quiz: Quiz 01 - Group AB, CD',
#  '3744': 'Quiz: Quiz 01 - Group AB, CD',
#  '3745': 'Quiz: Quiz 01 - Group AB, CD',
#  '3746': 'Quiz: Quiz 01 - Group AB, CD',
#  '3747': 'Quiz: Quiz 01 - Group AB, CD',
#  '3748': 'Quiz: Quiz 01 - Group AB, CD',
#  '3749': 'Quiz: Quiz 01 - Group AB, CD',
#  '3750': 'Quiz: Quiz 01 - Group AB, CD',
#  '3751': 'Quiz: Quiz 01 - Group AB, CD',
#  '3752': 'Quiz: Quiz 01 - Group AB, CD',
#  '3753': 'Quiz: Quiz 01 - Group AB, CD',
#  '3754': 'Quiz: Quiz 01 - Group AB, CD',
#  '3755': 'Quiz: Quiz 01 - Group AB, CD',
#  '3756': 'Quiz: Quiz 01 - Group AB, CD',
#  '3757': 'Quiz: Quiz 01 - Group AB, CD',
#  '3758': 'Quiz: Quiz 01 - Group AB, CD',
#  '3759': 'Quiz: Quiz 01 - Group AB, CD',
#  '3760': 'Quiz: Quiz 01 - Group AB, CD',
#  '3761': 'Quiz: Quiz 01 - Group AB, CD',
#  '3762': 'Quiz: Quiz 01 - Group AB, CD',
#  '3763': 'Quiz: Quiz 01 - Group AB, CD',
#  '3764': 'Quiz: Quiz 01 - Group AB, CD',
#  '3765': 'Quiz: Quiz 01 - Group AB, CD',
#  '3766': 'Quiz: Quiz 01 - Group AB, CD',
#  '3767': 'Quiz: Quiz 01 - Group AB, CD',
#  '3768': 'Quiz: Quiz 01 - Group AB, CD',
#  '3769': 'Quiz: Quiz 01 - Group AB, CD',
#  '3770': 'Quiz: Quiz 01 - Group AB, CD',
#  '3771': 'Quiz: Quiz 01 - Group AB, CD',
#  '3772': 'Quiz: Quiz 01 - Group AB, CD',
#  '3773': 'Quiz: Quiz 01 - Group AB, CD',
#  '3774': 'Quiz: Quiz 01 - Group AB, CD',
#  '3775': 'Quiz: Quiz 01 - Group AB, CD',
#  '3776': 'Quiz: Quiz 01 - Group AB, CD',
#  '3777': 'Quiz: Quiz 01 - Group AB, CD',
#  '3778': 'Quiz: Quiz 01 - Group AB, CD',
#  '3780': 'Quiz: Quiz 01 - Group AB, CD',
#  '3781': 'Quiz: Quiz 01 - Group AB, CD',
#  '3782': 'Quiz: Quiz 01 - Group AB, CD',
#  '3783': 'Quiz: Quiz 01 - Group AB, CD',
#  '3784': 'Quiz: Quiz 01 - Group AB, CD',
#  '3785': 'Quiz: Quiz 01 - Group AB, CD',
#  '3786': 'Quiz: Quiz 01 - Group AB, CD',
#  '3787': 'Quiz: Quiz 01 - Group AB, CD',
#  '3789': 'Quiz: Quiz 01 - Group AB, CD',
#  '3790': 'Quiz: Quiz 01 - Group AB, CD',
#  '3791': 'Quiz: Quiz 01 - Group AB, CD',
#  '3792': 'Quiz: Quiz 01 - Group AB, CD',
#  '3793': 'Quiz: Quiz 01 - Group AB, CD',
#  '3794': 'Quiz: Quiz 01 - Group AB, CD',
#  '3795': 'Quiz: Quiz 01 - Group AB, CD',
#  '3796': 'Quiz: Quiz 01 - Group AB, CD',
#  '3797': 'Quiz: Quiz 01 - Group AB, CD',
#  '3798': 'Quiz: Quiz 01 - Group AB, CD',
#  '3799': 'Quiz: Quiz 01 - Group AB, CD',
#  '3800': 'Quiz: Quiz 01 - Group AB, CD',
#  '3801': 'Quiz: Quiz 01 - Group AB, CD',
#  '3802': 'Quiz: Quiz 01 - Group AB, CD',
#  '3803': 'Quiz: Quiz 01 - Group AB, CD',
#  '3804': 'Quiz: Quiz 01 - Group AB, CD',
#  '3805': 'Quiz: Quiz 01 - Group AB, CD',
#  '3806': 'Quiz: Quiz 01 - Group AB, CD',
#  '3807': 'Quiz: Quiz 01 - Group AB, CD',
#  '3808': 'Quiz: Quiz 01 - Group AB, CD',
#  '3809': 'Quiz: Quiz 01 - Group AB, CD',
#  '3810': 'Quiz: Quiz 01 - Group AB, CD',
#  '3811': 'Quiz: Quiz 01 - Group AB, CD',
#  '3812': 'Quiz: Quiz 01 - Group AB, CD',
#  '3813': 'Quiz: Quiz 01 - Group AB, CD',
#  '3814': 'Quiz: Quiz 01 - Group AB, CD',
#  '3815': 'Quiz: Quiz 01 - Group AB, CD',
#  '3816': 'Quiz: Quiz 01 - Group AB, CD',
#  '3817': 'Quiz: Quiz 01 - Group AB, CD',
#  '3818': 'Quiz: Quiz 01 - Group AB, CD',
#  '3819': 'Quiz: Quiz 01 - Group AB, CD',
#  '3820': 'Quiz: Quiz 01 - Group AB, CD',
#  '3821': 'Quiz: Quiz 01 - Group AB, CD',
#  '3822': 'Quiz: Quiz 01 - Group AB, CD',
#  '3823': 'Quiz: Quiz 01 - Group AB, CD',
#  '3824': 'Quiz: Quiz 01 - Group AB, CD',
#  '3825': 'Quiz: Quiz 01 - Group AB, CD',
#  '3826': 'Quiz: Quiz 01 - Group AB, CD',
#  '3827': 'Quiz: Quiz 01 - Group AB, CD',
#  '3828': 'Quiz: Quiz 01 - Group AB, CD',
#  '3829': 'Quiz: Quiz 01 - Group AB, CD',
#  '3830': 'Quiz: Quiz 01 - Group AB, CD',
#  '3831': 'Quiz: Quiz 01 - Group AB, CD',
#  '3832': 'Quiz: Quiz 01 - Group AB, CD',
#  '3833': 'Quiz: Quiz 01 - Group AB, CD',
#  '3834': 'Quiz: Quiz 01 - Group AB, CD',
#  '3836': 'Quiz: Quiz 01 - Group AB, CD',
#  '3837': 'Quiz: Quiz 01 - Group AB, CD',
#  '3838': 'Quiz: Quiz 01 - Group AB, CD',
#  '3839': 'Quiz: Quiz 01 - Group AB, CD',
#  '3886': 'Quiz: Quiz 01 - Group AB, CD',
#  '3889': 'Quiz: Quiz 01 - Group AB, CD',
#  '3890': 'Quiz: Quiz 01 - Group AB, CD',
#  '3891': 'Quiz: Quiz 01 - Group AB, CD',
#  '3892': 'Quiz: Quiz 01 - Group AB, CD',
#  '3893': 'Quiz: Quiz 01 - Group AB, CD',
#  '3894': 'Quiz: Quiz 01 - Group AB, CD',
#  '3895': 'Quiz: Quiz 01 - Group AB, CD',
#  '3896': 'Quiz: Quiz 01 - Group AB, CD',
#  '3897': 'Quiz: Quiz 01 - Group AB, CD',
#  '3898': 'Quiz: Quiz 01 - Group AB, CD',
#  '3899': 'Quiz: Quiz 01 - Group AB, CD',
#  '3900': 'Quiz: Quiz 01 - Group AB, CD',
#  '3901': 'Quiz: Quiz 01 - Group AB, CD',
#  '3902': 'Quiz: Quiz 01 - Group AB, CD',
#  '3903': 'Quiz: Quiz 01 - Group AB, CD',
#  '3904': 'Quiz: Quiz 01 - Group AB, CD',
#  '3905': 'Quiz: Quiz 01 - Group AB, CD',
#  '3906': 'Quiz: Quiz 01 - Group AB, CD',
#  '3907': 'Quiz: Quiz 01 - Group AB, CD',
#  '3908': 'Quiz: Quiz 01 - Group AB, CD',
#  '3909': 'Quiz: Quiz 01 - Group AB, CD',
#  '3910': 'Quiz: Quiz 01 - Group AB, CD',
#  '3911': 'Quiz: Quiz 01 - Group AB, CD',
#  '3912': 'Quiz: Quiz 01 - Group AB, CD',
#  '3913': 'Quiz: Quiz 01 - Group AB, CD',
#  '3914': 'Quiz: Quiz 01 - Group AB, CD (Attempt 3)',
#  '3915': 'Quiz: Quiz 01 - Group AB, CD',
#  '3916': 'Quiz: Quiz 01 - Group AB, CD',
#  '3917': 'Quiz: Quiz 01 - Group AB, CD',
#  '3918': 'Quiz: Quiz 01 - Group AB, CD',
#  '3919': 'Quiz: Quiz 01 - Group AB, CD',
#  '3920': 'Quiz: Quiz 01 - Group AB, CD',
#  '3921': 'Quiz: Quiz 01 - Group AB, CD',
#  '3922': 'Quiz: Quiz 01 - Group AB, CD',
#  '3923': 'Quiz: Quiz 01 - Group AB, CD',
#  '3924': 'Quiz: Quiz 01 - Group AB, CD',
#  '3925': 'Quiz: Quiz 01 - Group AB, CD',
#  '3926': 'Quiz: Quiz 03 - Functions - AB',
#  '3927': 'Quiz: Quiz 01 - Group AB, CD',
#  '3928': 'Quiz: Quiz 01 - Group AB, CD',
#  '3929': 'Quiz: Quiz 01 - Group AB, CD',
#  '3930': 'Quiz: Quiz 01 - Group AB, CD',
#  '3931': 'Quiz: Quiz 01 - Group AB, CD',
#  '3932': 'Quiz: Quiz 01 - Group AB, CD',
#  '3933': 'Quiz: Quiz 01 - Group AB, CD',
#  '3934': 'Quiz: Quiz 01 - Group AB, CD',
#  '3935': 'Quiz: Quiz 01 - Group AB, CD',
#  '3936': 'Quiz: Quiz 01 - Group AB, CD',
#  '3937': 'Quiz: Quiz 01 - Group AB, CD',
#  '3938': 'Quiz: Quiz 01 - Group AB, CD',
#  '972': 'Quiz: Quiz 06 - Object Oriented Programming'}

# %%
#quiz['user1'] = quiz['Description'].apply(userId)
des['user'] = des['Description'].apply(userId)
